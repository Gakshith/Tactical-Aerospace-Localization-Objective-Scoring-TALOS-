# %%
import box
print(box.__version__)
# Out:
# 7.3.2

# %%
import box
print(f"Box version: {box.__version__}")

from box import ConfigBox
dicti = {"hi": 1, "akshith": 2}
data = ConfigBox(dicti)
print(f"Success! Accessing 'akshith': {data.akshith}")
# Out:
# Box version: 7.3.2
# Success! Accessing 'akshith': 2

# %%
import sys
# !{sys.executable} -m pip install box
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for timeago: filename=timeago-1.0.14-py3-none-any.whl size=26483 sha256=8ce0f4db3af0dfcb87d63c44a21afeb5dd22fcd0d7d49a86fe9168a18f3c6d8c
#   Stored in directory: /Users/gojuruakshith/Library/Caches/pip/wheels/f5/73/dc/a323663cd480162282919beda31fb477774163b5e56436f81a
# Successfully built timeago
# ...
#   Attempting uninstall: executing
#     Found existing installation: executing 2.2.1
#     Uninstalling executing-2.2.1:
#       Successfully uninstalled executing-2.2.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [box]6/7 [box]
# ...

# %%
import sys
# !{sys.executable} -m pip install ensure==1.0.4
# Out:
# ...
#   Using cached ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached ensure-1.0.4-py3-none-any.whl (15 kB)
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /usr/local/bin/python3.14 -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.4.14-py3-none-any.whl.metadata (39 kB)
# ...
#   Using cached matplotlib-3.10.8-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached pillow-12.1.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached torch-2.10.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (31 kB)
# ...
#   Using cached torchvision-0.25.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.4 kB)
# ...
#   Using cached polars-1.38.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (6.3 kB)
# ...

# %%
import sys
# !{sys.executable} -m pip install kagglehub
# Out:
# ...
#   Using cached kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# ...
#   Using cached kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# ...
# Using cached kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Using cached kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Using cached protobuf-6.33.5-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [kagglehub]/3 [kagglesdk]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /usr/local/bin/python3.14 -m pip install --upgrade pip
