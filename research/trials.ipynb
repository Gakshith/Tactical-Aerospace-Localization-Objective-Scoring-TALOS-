# %%
import box
from ultralytics import YOLO
from matplotlib import pyplot as plt
# print(box.__version__)

# %%
from box import ConfigBox
dicti = {"hi": 1, "akshith": 2}
# data = ConfigBox(dicti)
# print(f"Success! Accessing 'akshith': {data.akshith}")
# print(f"Accessing 'hi': {data.hi}")

# %%
pip uninstall box -y
pip uninstall python-box -y
pip install python-box==7.1.1

# %%
import sys
# !{sys.executable} -m pip install python-box==7.1.1
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /usr/local/bin/python3.14 -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install ensure==1.0.4
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /usr/local/bin/python3.14 -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install ultralytics
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /usr/local/bin/python3.14 -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install kagglehub
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /usr/local/bin/python3.14 -m pip install --upgrade pip

# %%
from pathlib import Path
model = YOLO(Path("runs/detect/train3/weights/best.pt"))

# %%
result =model.predict(Path("artifacts/data_transformation/images/val/img401.png"))
# Out:
# image 1/1 /Users/gojuruakshith/Tactical-Aerospace-Localization-Objective-Scoring-TALOS-/artifacts/data_transformation/images/val/img401.png: 736x1024 5 planes, 199.1ms
# Speed: 5.2ms preprocess, 199.1ms inference, 0.1ms postprocess per image at shape (1, 3, 736, 1024)

# %%
import cv2
res = result[0]
annotated_img = res.plot()
annotated_img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
# Display the result
plt.figure(figsize=(10, 10))
plt.imshow(annotated_img_rgb)
plt.axis('off')
plt.show()

# %%
ls
# Out:
# data_ingestion.ipynb       model_train.ipynb
# data_transformation.ipynb  trials.ipynb
# data_validation.ipynb

# %%
cd ..
# Out:
# /Users/gojuruakshith/Tactical-Aerospace-Localization-Objective-Scoring-TALOS-
